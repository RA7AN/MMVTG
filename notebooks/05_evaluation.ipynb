# %% [markdown]
# # 05 — Evaluation
#
# **TODO:** This notebook will guide you through evaluating a trained model.
#
# ## Expected Contents
#
# - Load fine-tuned checkpoint
# - Run evaluation on test split
# - Compute metrics (R1@0.5, R1@0.7, mAP)
# - Visualize results

# %%
# TODO: Implement evaluation steps
print("Evaluation notebook - coming soon")
