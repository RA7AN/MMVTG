# %% [markdown]
# # 06 — Inference
#
# **TODO:** This notebook will guide you through running inference with a trained checkpoint.
#
# ## Expected Contents
#
# - Load fine-tuned checkpoint
# - Load video and query
# - Run moment prediction
# - Visualize predicted moments

# %%
# TODO: Implement inference steps
print("Inference notebook - coming soon")
