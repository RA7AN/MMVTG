# %% [markdown]
# # 07 — FIR-Grounded Inference
#
# **TODO:** This notebook will guide you through inference augmented with FIR reports.
#
# ## Expected Contents
#
# - Load FIR report (First Information Report)
# - Combine query with FIR context
# - Run grounded inference
# - Compare with standard inference results

# %%
# TODO: Implement grounded inference steps
print("Grounded inference notebook - coming soon")
